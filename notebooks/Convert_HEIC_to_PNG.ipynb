# %% [markdown]
# ## A notebook to convert images in HEIC format to the one you'd want

# %%
# Installing the heif library in python
# !pip install pyheif
# Out:
# WARNING: The directory '/home/saurabh.nair/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting pyheif
#   Downloading pyheif-0.7.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pyheif) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.0.0->pyheif) (2.21)
# Installing collected packages: pyheif
# Successfully installed pyheif-0.7.0

# %%
source_with_heic_images = "/data/aiscience/data/SpiritLevel/"
target_folder = "/data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/"
output_image_extension = "PNG"

# %%
import os

import pyheif
from PIL import Image


def read_heif_image(source_image_dir) -> Image:
    """
    Args: Directory of the heif image.
    
    Returns: The loaded heif image.
    
    """
    heif_file = pyheif.read(source_image_dir)
    image = Image.frombytes(
        heif_file.mode, 
        heif_file.size, 
        heif_file.data,
        "raw",
        heif_file.mode,
        heif_file.stride,
    )
    return image

# %%
def convert_file(file_name, source_with_heic_images, output_image_extension):
    source_file = os.path.join(source_with_heic_images, file_name)
    image_name, extension = os.path.splitext(file_name)
    image = read_heif_image(
        source_image_dir=source_file, 
    )
    new_image_dir = f"{target_folder}{image_name}.{output_image_extension.lower()}"
    
    image.save(new_image_dir, output_image_extension)
    print(f"Saved converted image of {file_name} at: {new_image_dir}")

# %%
os.makedirs(target_folder, exist_ok=True)
from multiprocessing import Process
processes = []
for file_name in os.listdir(source_with_heic_images):
    #convert_file(file_name, source_with_heic_images, output_image_extension)
    p = Process(target=convert_file, args=(file_name, source_with_heic_images, output_image_extension))
    p.start()
    processes.append(p)
    
for process in processes:
    process.join()
# Out:
# Saved converted image of IMG_2311.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2311.png
# Saved converted image of IMG_2217.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2217.png
# Saved converted image of IMG_2212.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2212.png
# Saved converted image of IMG_2287.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2287.png
# Saved converted image of IMG_2350.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2350.png
# Saved converted image of IMG_2222.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2222.png
# Saved converted image of IMG_2244.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2244.png
# Saved converted image of IMG_2214.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2214.png
# Saved converted image of IMG_2336.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2336.pngSaved converted image of IMG_2241.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2241.png
# Saved converted image of IMG_2219.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2219.png
#
# Saved converted image of IMG_2209.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2209.pngSaved converted image of IMG_2289.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2289.png
#
# Saved converted image of IMG_2216.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2216.pngSaved converted image of IMG_2243.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2243.png
#
# Saved converted image of IMG_2279.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2279.pngSaved converted image of IMG_2207.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2207.pngSaved converted image of IMG_2213.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2213.png
#
#
# Saved converted image of IMG_2236.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2236.pngSaved converted image of IMG_2223.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2223.png
#
# Saved converted image of IMG_2312.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2312.pngSaved converted image of IMG_2237.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_
HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2266.png
#
# Saved converted image of IMG_2231.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2231.png
# Saved converted image of IMG_2346.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2346.png
#
#
# Saved converted image of IMG_2248.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2248.pngSaved converted image of IMG_2270.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2270.pngSaved converted image of IMG_2263.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2263.png
#
#
#
# Saved converted image of IMG_2306.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2306.pngSaved converted image of IMG_2255.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2255.pngSaved converted image of IMG_2210.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2210.pngSaved converted image of IMG_2272.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2272.png
# Saved converted image of IMG_2308.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2308.pngSaved converted image of IMG_2310.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2310.png
#
#
#
#
# Saved converted image of IMG_2327.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2327.png
# Saved converted image of IMG_2333.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2333.pngSaved converted image of IMG_2301.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2301.pngSaved converted image of IMG_2294.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2294.pngSaved converted image of IMG_2261.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2261.png
#
# Saved converted image of IMG_2262.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2262.png
# Saved converted image of IMG_2324.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2324.png
# Saved converted image of IMG_2296.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2296.pngSaved converted image of IMG_2318.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2318.pngSaved converted image of IMG_2342.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2342.pngSaved converted image of IMG_2317.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2317.png
#
#
#
# Saved converted image of IMG_2353.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2353.png
#
# Saved converted image of IMG_2300.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2300.pngSaved converted image of IMG_2305.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2305.pngSaved converted image of IMG_2330.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2330.pngSaved converted image of IMG_2304.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2304.png
# Saved converted image of IMG_2303.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2303.png
#
# Saved converted image of IMG_2314.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2314.png
# Saved converted image of IMG_2326.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2326.pngSaved converted image of IMG_2349.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2349.png
# Saved converted image of IMG_2269.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2269.png
#
#
# Saved converted image of IMG_2254.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2254.pngSaved converted image of IMG_2331.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2331.png
#
# Saved converted image of IMG_2335.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2335.pngSaved converted image of IMG_2337.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2337.png
#
#
#
# Saved converted image of IMG_2253.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2253.png
# Saved converted image of IMG_2288.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2288.pngSaved converted image of IMG_2348.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2348.pngSaved converted image of IMG_2267.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2267.pngSaved converted image of IMG_2322.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2322.pngSaved converted image of IMG_2274.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2274.pngSaved converted image of IMG_2292.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2292.png
#
# Saved converted image of IMG_2329.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2329.png
#
#
# Saved converted image of IMG_2334.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2334.pngSaved converted image of IMG_2297.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2297.png
#
#
#
# Saved converted image of IMG_2332.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2332.pngSaved converted image of IMG_2344.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2344.pngSaved converted image of IMG_2325.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2325.pngSaved converted image of IMG_2321.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2321.pngSaved converted image of IMG_2341.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2341.png
#
#
#
#
# Saved converted image of IMG_2343.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2343.pngSaved converted image of IMG_2328.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2328.png
# Saved converted image of IMG_2347.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2347.png
# Saved converted image of IMG_2352.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2352.png
#
# Saved converted image of IMG_2345.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2345.pngSaved converted image of IMG_2323.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2323.pngSaved converted image of IMG_2339.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2339.png
# Saved converted image of IMG_2340.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2340.pngSaved converted image of IMG_2319.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2319.png
#
#
#
# Saved converted image of IMG_2320.HEIC at: /data/pixtrack/pixel-perfect-sfm/datasets/spirit_level_07122022/mapping/IMG_2320.png
